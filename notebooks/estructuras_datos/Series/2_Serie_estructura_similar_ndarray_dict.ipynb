# %% [markdown]
# # Serie como ```ndarray``` o un ```dict``` (diccionario)📔

# %% [markdown]
# ## 1. Series se comporta como un _ndarray_ de NumPy
# Serie permite:
#  - La __indexación por posición__,
#  - El __slicing__ (rebanando) y
#  - La aplicación directa de __funciones universales__.

# %%
import pandas as pd
import numpy as np
#Creacipon de la serie
np.random.seed(42) # Para resultados consistentes
s = pd.Series(np.random.randn(5), list("abcde"))
print(s)
# Out:
# a    0.496714
# b   -0.138264
# c    0.647689
# d    1.523030
# e   -0.234153
# dtype: float64

# %% [markdown]
# ### 1.1. Slicing y acceso basado en posiciones : ```s.iloc[loc]```
# Acceso a los elementos de la serie __independientemente__ del ```índice``` (etiquetas) de la serie.

# %%
#1. Slicing y acceso basado en una posición entera (iloc)
primer_elemento = s.iloc[0]
primer_elemento
print(type(primer_elemento))
print("=" * 50)
print(f"Primero elemento:\n{primer_elemento:.6f}")
# Out:
# <class 'numpy.float64'>
# ==================================================
# Primero elemento:
# 0.496714

# %%
#2. Slicing por rango de posiciones
tres_primeros = s.iloc[:3]
print(type(tres_primeros))
print("=" * 40)
print(f"Tres primeros elementos : \n{tres_primeros}")
# Out:
# <class 'pandas.core.series.Series'>
# ========================================
# Tres primeros elementos :
# a    0.496714
# b   -0.138264
# c    0.647689
# dtype: float64

# %%
#3. Acceso basado en en una rango de posiciones con un salto
seleccion_iloc = s.iloc[1:4:2]
print(f"Serie completa:\n{s}")
print("=" * 60)
print(type(seleccion_iloc))
print("=" * 60)
print(f"Acceso basado en posiciones específicas y reordenadas:\n{seleccion_iloc}")
# Out:
# Serie completa:
# a    0.496714
# b   -0.138264
# c    0.647689
# d    1.523030
# e   -0.234153
# dtype: float64
# ============================================================
# <class 'pandas.core.series.Series'>
# ============================================================
# Acceso basado en posiciones específicas y reordenadas:
# b   -0.138264
# d    1.523030
# dtype: float64

# %% [markdown]
# ### 1.2. Operaciones condicionales (Indexación booleana): usado para filtrar

# %%
mediana_s = s.median()
#Se filtran los valores que son mayores a la mediana
s_filtrada = s[ s > mediana_s]

print(f"Serie completa:\n{s}")
print("=" * 50)
print(f"Mediana de las series: {mediana_s}")
print("=" * 50)
print(f"Valor de la 's' mayores a la mediana:\n{s_filtrada}")
# Out:
# Serie completa:
# a    0.496714
# b   -0.138264
# c    0.647689
# d    1.523030
# e   -0.234153
# dtype: float64
# ==================================================
# Mediana de las series: 0.4967141530112327
# ==================================================
# Valor de la 's' mayores a la mediana:
# c    0.647689
# d    1.523030
# dtype: float64

# %% [markdown]
# En el ejemplo anterior: __cada valor__ de ```s``` se compara con la mediana, es como decir dame los elementos de ```s``` donde la condicion sea ```True```.
# ### 1.3. Aplicación de funciones universales

# %%
#Aplicación de funciones NumPy a una serie de Panda
s_exp = np.exp(s)
print("Serie original:")
print(s)
print("=" * 40)
print("Resultado al aplicar no.exp(s): ")
print(s_exp)
# Tipos de datos de una serie de panda (tipo de datos de los valores que almacena)
print("=" * 40)
print("Tipo de dato de la serie 's': ")
print(s.dtype)
# Out:
# Serie original:
# a    0.496714
# b   -0.138264
# c    0.647689
# d    1.523030
# e   -0.234153
# dtype: float64
# ========================================
# Resultado al aplicar no.exp(s):
# a    1.643313
# b    0.870868
# c    1.911118
# d    4.586099
# e    0.791240
# dtype: float64
# ========================================
# Tipo de dato de la serie 's':
# float64

# %% [markdown]
# ### 1.4. Acceso al Array Subyacente
# En el caso que necesitemos interactuar con el array de __datos puros__ (sín los índices de pandas).
# #### ```s.array```

# %%
#A. Extensión Array de pandas: 
array_extension = s.array
print("Acceso al array subyacente con s.array (ExtensionArray):")
print(array_extension)
print("=" * 70)
print(f"Tipo de objeto:\n{type(array_extension)}")
# Out:
# Acceso al array subyacente con s.array (ExtensionArray):
# <NumpyExtensionArray>
# [  0.4967141530112327, -0.13826430117118466,   0.6476885381006925,
#    1.5230298564080254, -0.23415337472333597]
# Length: 5, dtype: float64
# ======================================================================
# Tipo de objeto:
# <class 'pandas.core.arrays.numpy_.NumpyExtensionArray'>

# %% [markdown]
# #### ```s.to_numpy()```
# Este método __devuelve__ un ```np.ndarray``` estándar, sin importar que extensión esté respaldando la serie.

# %%
#B. Array Puro de Numpy, con el método: to_numpy()
array_numpy = s.to_numpy()
print("Acceso s.to_numpy() (ndarray puro de NumPy):")
print(array_numpy)
print(f"Tipo de objeto:\n{type(array_numpy)}")
# Out:
# Acceso s.to_numpy() (ndarray puro de NumPy):
# [ 0.49671415 -0.1382643   0.64768854  1.52302986 -0.23415337]
# Tipo de objeto:
# <class 'numpy.ndarray'>

# %% [markdown]
# ## 2. Serie como un diccionario de __tamaño fijo__.
# Permiten interactuar con los datos usando sus __etiquetas de índice__, similar como las __claves__ de un diccionario.

# %%
#A.Series con etiquetas de texto y valores numéricos
np.random.seed(42)
s = pd.Series(np.random.randn(5), ["A", "B", "C", "D", "E"])
print(f"Series con etiquetas de textos y valores numéricos:\n{s}")
# Out:
# Series con etiquetas de textos y valores numéricos:
# A    0.496714
# B   -0.138264
# C    0.647689
# D    1.523030
# E   -0.234153
# dtype: float64

# %% [markdown]
# ### 2.1. Obtener valores por etiqueta: ```s[etiqueta]```🏷️

# %%
print(f'Serie:\n{s}')
print("=" * 50)
print("Obtenemos un valor por su etiqueta:")
#Accedemos a un valor por si etiqueta
valor_A = s["D"]
print(f'Valor relacionado a la etiqueta "D": {valor_A : .4f}')
# Out:
# Serie:
# A    0.496714
# B   -0.138264
# C    0.647689
# D    1.523030
# E   -0.234153
# dtype: float64
# ==================================================
# Obtenemos un valor por su etiqueta:
# Valor relacionado a la etiqueta "D":  1.5230

# %% [markdown]
# ### 2.2. Establecer un valor por etiqueta: ```s[etiqueta] = valor```

# %%
print(f'Valor de etiqueta B, antes: {s["B"]}')
print("=" * 60)
print('Cambiamos el valor relacionado a a la etiqueta "B":')
print("=" * 60)
#Si la etiqueta existe, se sobreescribe el valor
s["B"] = -0.00022224
print(f'Valor de la etiqueta "B", después: {s["B"]}')
# Out:
# Valor de etiqueta B, antes: -0.00022224
# ============================================================
# Cambiamos el valor relacionado a a la etiqueta "B":
# ============================================================
# Valor de la etiqueta "B", después: -0.00022224

# %% [markdown]
# En el caso de que la etiqueta no exista, se agregará el valor y su etiqueta al final de la serie.
#
# ```s[etiqueta_no_exise] = valor```

# %%
print(f"Serie, antes:\n{s}")
print("=" * 30)
s["L"] = -0.0004444
print(f"Serie, después:\n{s}")
# Out:
# Serie, antes:
# A    0.496714
# B   -0.000222
# C    0.647689
# D    1.523030
# E   -0.234153
# dtype: float64
# ==============================
# Serie, después:
# A    0.496714
# B   -0.000222
# C    0.647689
# D    1.523030
# E   -0.234153
# L   -0.000444
# dtype: float64

# %% [markdown]
# ### 2.3. Verificar si una etiqueta pertence al índice: ```Variable = etiqueta in s```

# %%
# C. Verificamos si una etiqueta existe en el índice de la serie
# Las etiquetas son sensibles a mayúsculas y minúsculas
existe_E = "E" in s
existe_e = "e" in s
existe_M = "M" in s
print(f'Existe la etiqueta "E" en la serie: {existe_E}')
print(f'Existe la etiqueta "e" en la serie: {existe_e}')
print(f'Existe la etiqueta "M" en la serie: {existe_e}')
# Out:
# Existe la etiqueta "E" en la serie: True
# Existe la etiqueta "e" en la serie: False
# Existe la etiqueta "M" en la serie: False

# %% [markdown]
# En el caso de queramos obtener un valor de una __etiqueta que no existe__ en el índice de la serie, usando [ ], pandas lanzará un ```KeyError```.

# %%
#D. Menejo de errores: KeyError 
try:
    s["M"]
except KeyError as e:
    print(f'❌Se produjo un {type(e).__name__} al intentar acceder a la etiqueta "M"')
    print(f"Mensaje: {e}")
# Out:
# ❌Se produjo un KeyError al intentar acceder a la etiqueta "M"
# Mensaje: 'M'

# %% [markdown]
# ### 2.4. Forma segura de acceder a etiquetas: ```s.get()```
# El método ```get()``` es la forma segura de acceder a etiquetas, ya que si no existe, devuelve ```None``` (valor prdeterminado en vez de generar un error).

# %%
# E. Uso del método get()para evitar errores
#E.1. Método: get() sin valor predeterminado
valor_M_none = s.get("M")
print(f'\nResultado de .get("M"): {valor_M_none}')
print(f"Tipo de resultado: {type(valor_M_none)}")
# Out:
# Resultado de .get("M"): None
# Tipo de resultado: <class 'NoneType'>

# %% [markdown]
# Podemos especificar un __valor por defecto__, si la etiqueta no se encuentra, sirve para __manejar valor faltantes__ (como np.nan).

# %%
#E.2. Método: .get() con valor predeterminado
valor_G_nan = s.get("G", np.nan)
print(f'Resultado de s.get("G", np.nan): {valor_G_nan}')
print(f'Tipo: {type(valor_G_nan)}')
# Out:
# Resultado de s.get("G", np.nan): nan
# Tipo: <class 'float'>

# %% [markdown]
# ### 2.5. Acceso directo al valor por atributo: ```s.Etiqueta```
#  - Las etiquetas que cumples con las reglas de nombres de variables de Python
#  - También pueden accederse como atributos de la Series
#  - Es menos recomendable que ```loc[Etiqueta]``` para evitar conflictos de nombres con métodos de pandas.

# %%
valor_atributo_A = s.A
print(f'🏷️Acceso directo a un valor por atributo (s.A): {valor_atributo_A:.6f}')
# Out:
# 🏷️Acceso directo a un valor por atributo (s.A): 0.496714
