# %% [markdown]
# # Exploración de índices y columnas📘
#  - __El ```índice```:__ identifica las filas de un ```DataFrame``` o ```Series```.
#  - __Las ```columnas```:__ representan las variables(atributos o identificadores de las columnas) en un DataFrame.
#
#  Ambos son objetos ```pandas.index```, inmutables y potentes para operaciones de alineación, selección y combinación.

# %% [markdown]
# ## 1. Firmas de métodos y atributos principales🐼
# ### 1.1. En un ```DataFrame```🧱
# ```
# DataFrame.index -> pandas.Index
# DataFrame.columns -> pandas.Index
# DataFrame.axes -> list[Index]
# DataFrame.keys() -> Index
# DataFrame.get_axis_number(axis: int | str) -> int
# DataFrame.get_axis(axis: int | str) -> Index
# ```

# %% [markdown]
# ### 1.1. En ```Series```🧩
# ```
# Series.index -> pandas.Index
# Series.axes -> list[Index]
# Series.keys() -> Index
# Series.get_axis_number(axis: int | str) -> int
# Series.get_axis(axis: int | str) -> Index
# ```

# %% [markdown]
# ## 2. Método y objeto ```Index```
# ### 2.1 Firma de objeto ```Index```:
# Creación de un objeto ```Index``` mediante pandas:
# ```
# pandas.Index(data=None, dtype=None, copy=False, name=None, tupleize_cols=True)
# ```
# ### 2.2. Métodos relevantes del __objeto__ ```Index```:
# aAplican tanto a índices de ```Series``` como de ```DataFrame```:
# ```
# Index.values -> ndarray
# Index.tolist() -> list
# Index.name -> str
# Index.names -> list[str]  # MultiIndex
# Index.is_unique -> bool
# Index.has_duplicates -> bool
# Index.equals(other: Index) -> bool
# Index.rename(name, inplace=False) -> Index
# Index.set_names(names, level=None, inplace=False) -> Index
# Index.get_loc(key) -> int
# Index.get_indexer(target) -> ndarray
# Index.append(other) -> Index
# Index.union(other) -> Index
# Index.intersection(other) -> Index
# Index.difference(other) -> Index
# Index.symmetric_difference(other) -> Index
# Index.sort_values() -> Index
# Index.drop(labels) -> Index
# Index.insert(loc, item) -> Index
# Index.delete(loc) -> Index
# Index.repeat(repeats) -> Index
# Index.duplicated() -> ndarray
# Index.map(func) -> Index
# ```
